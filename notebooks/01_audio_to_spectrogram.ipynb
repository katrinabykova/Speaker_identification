# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from src.data import display_audio

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Examine audio files
file = '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/174/168635/174-168635-0002.flac'
display_audio.play_audio(file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Display wave plot 
display_audio.display_waveplot(file)

# %%
# Display spectrogram
display_audio.display_spectrogram(file)
