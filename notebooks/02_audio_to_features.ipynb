# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas
import numpy as np
import pickle

from src.data import process_files
from src.data import process_audio
from src.data import audio_to_features
from src.data import features_for_model
# Out:
# Using TensorFlow backend.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # VGG16 features

# %% [markdown]
# ## Train data

# %%
# Process audio files and add extracted features to a dataframe
train_path = '/Users/greenapple/project5/data/raw/LibriSpeech/train-clean-360'
speaker_start = 0
speaker_stop_10 = 10
speaker_stop_900 = 900

# Dataframe for 10 speakers
train_data_10_vgg = audio_to_features.VGG16_features(train_path, speaker_start, speaker_stop_10)# extract data
pickle.dump(train_data_10_vgg, open(
'/Users/greenapple/project5/data/processed/train_data_10_vgg.pkl', 'wb')) # save data

# Dataframe for 900 speakers (all)
train_data_900_vgg = audio_to_features.VGG16_features(train_path, speaker_start, speaker_stop_900)# extract data 
pickle.dump(train_data_900_vgg, open(
'/Users/greenapple/project5/data/processed/train_data_900_vgg.pkl', 'wb')) # save data
# Out:
# Done with speaker 1, have 10 audio files
# Done with speaker 2, have 10 audio files
# Done with speaker 3, have 10 audio files
# Done with speaker 4, have 10 audio files
# Done with speaker 5, have 10 audio files
# Done with speaker 6, have 10 audio files
# Done with speaker 7, have 10 audio files
# Done with speaker 8, have 10 audio files
# Done with speaker 9, have 10 audio files
# Done with speaker 10, have 10 audio files
# Done with speaker 1, have 10 audio files
# Done with speaker 2, have 10 audio files
# Done with speaker 3, have 10 audio files
# Done with speaker 4, have 10 audio files
# Done with speaker 5, have 10 audio files
# Done with speaker 6, have 10 audio files
# Done with speaker 7, have 10 audio files
# Done with speaker 8, have 10 audio files
# Done with speaker 9, have 10 audio files
# Done with speaker 10, have 10 audio files
# Done with speaker 11, have 10 audio files
# Done with speaker 12, have 10 audio files
# Done with speaker 13, have 10 audio files
# ...

# %% [markdown]
# ## Test data

# %%
# Process audio files and add extracted features to a dataframe
test_path = '/Users/greenapple/project5/data/raw/LibriSpeech/test-clean'
speaker_start = 0
speaker_stop_40 = 40

# Dataframe for 40 speakers (all)
test_data_40_vgg = audio_to_features.VGG16_features(test_path, speaker_start, speaker_stop_40) # extract data 
pickle.dump(test_data_40_vgg, open(
'/Users/greenapple/project5/data/processed/test_data_40_vgg.pkl', 'wb')) # save data
# Out:
# Done with speaker 1, have 10 audio files
# Done with speaker 2, have 10 audio files
# Done with speaker 3, have 10 audio files
# Done with speaker 4, have 10 audio files
# Done with speaker 5, have 10 audio files
# Done with speaker 6, have 10 audio files
# Done with speaker 7, have 10 audio files
# Done with speaker 8, have 10 audio files
# Done with speaker 9, have 10 audio files
# Done with speaker 10, have 10 audio files
# Done with speaker 11, have 10 audio files
# Done with speaker 12, have 10 audio files
# Done with speaker 13, have 10 audio files
# Done with speaker 14, have 10 audio files
# Done with speaker 15, have 10 audio files
# Done with speaker 16, have 10 audio files
# Done with speaker 17, have 10 audio files
# Done with speaker 18, have 10 audio files
# Done with speaker 19, have 10 audio files
# Done with speaker 20, have 10 audio files
# Done with speaker 21, have 10 audio files
# Done with speaker 22, have 10 audio files
# ...

# %% [markdown]
# ## Validation data

# %%
# Process audio files and add extracted features to a dataframe
val_path = '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean'
speaker_start = 0
speaker_stop_40 = 40

# Dataframe for 40 speakers (all)
val_data_40_vgg = audio_to_features.VGG16_features(val_path, speaker_start, speaker_stop_40)  
pickle.dump(val_data_40_vgg, open(
'/Users/greenapple/project5/data/processed/val_data_40_vgg.pkl', 'wb')) # save data
# Out:
# Done with speaker 1, have 10 audio files
# Done with speaker 2, have 10 audio files
# Done with speaker 3, have 10 audio files
# Done with speaker 4, have 10 audio files
# Done with speaker 5, have 10 audio files
# Done with speaker 6, have 10 audio files
# Done with speaker 7, have 10 audio files
# Done with speaker 8, have 10 audio files
# Done with speaker 9, have 10 audio files
# Done with speaker 10, have 10 audio files
# Done with speaker 11, have 10 audio files
# Done with speaker 12, have 10 audio files
# Done with speaker 13, have 10 audio files
# Done with speaker 14, have 10 audio files
# Done with speaker 15, have 10 audio files
# Done with speaker 16, have 10 audio files
# Done with speaker 17, have 10 audio files
# Done with speaker 18, have 10 audio files
# Done with speaker 19, have 10 audio files
# Done with speaker 20, have 10 audio files
# Done with speaker 21, have 10 audio files
# Done with speaker 22, have 10 audio files
# ...

# %% [markdown]
# # Spectrogram features

# %% [markdown]
# ## Train data

# %%
# Process audio files and add extracted features to a dataframe
train_path = '/Users/greenapple/project5/data/raw/LibriSpeech/train-clean-360'
speaker_start = 0
speaker_stop_900 = 900  

# Dataframe for 900 speakers (all)
train_data_900_spec = features_for_model.siamese_spec_features(train_path, speaker_start, speaker_stop_900)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-2c078dc8c511> in <module>
#       5
#       6 # Dataframe for 900 speakers (all)
# ----> 7 train_data_900_spec = audio_to_features.siamese_spec_features(train_path, speaker_start, speaker_stop_900)
#
# AttributeError: module 'src.data.audio_to_features' has no attribute 'siamese_spec_features'

# %% [markdown]
# ## Test data

# %%
# Process audio files and add extracted features to a dataframe
test_path = '/Users/greenapple/project5/data/raw/LibriSpeech/test-clean'
speaker_start = 0
speaker_stop_10 = 10
speaker_stop_40 = 40

# Dataframe for 10 speakers
test_data_10_spec = audio_to_features.siamese_spec_features(test_path, speaker_start, speaker_stop_10) 

# Dataframe for 40 speakers (all)
test_data_40_spec = audio_to_features.siamese_spec_features(test_path, speaker_start, speaker_stop_40)

# %% [markdown]
# ## Validation data

# %%
# Process audio files and add extracted features to a dataframe
val_path = '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean'
speaker_start = 0
speaker_stop_10 = 10
speaker_stop_40 = 40

# Dataframe for 10 speakers
val_data_10_spec = audio_to_features.siamese_spec_features(val_path, speaker_start, speaker_stop_10) 

# Dataframe for 40 speakers (all)
val_data_40_spec = audio_to_features.siamese_spec_features(val_path, speaker_start, speaker_stop_400)

# %% [markdown]
# # New features from longer audios - 9 sec.

# %% [markdown]
# ## VGG16 features

# %% [markdown]
# ### Validation data

# %%
# Use this cell to extract data:
# Process audio files and add extracted features to a dataframe. Longer, 9 sec audios.
val_path = '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean'
speaker_start = 0
speaker_stop = 40

# Dataframe for 40 speakers (all)
val_data_9sec = audio_to_features.VGG16_features_9_sec(val_path, 
                                                       speaker_start, 
                                                       speaker_stop)
# Out:
# Done with speaker 1, have 10 audio files
# Done with speaker 2, have 10 audio files
# Done with speaker 3, have 10 audio files
# Done with speaker 4, have 10 audio files
# Done with speaker 5, have 10 audio files
# Done with speaker 6, have 10 audio files
# Done with speaker 7, have 10 audio files
# Done with speaker 8, have 10 audio files
# Done with speaker 10, have 10 audio files
# Done with speaker 11, have 10 audio files
# Done with speaker 12, have 10 audio files
# Done with speaker 13, have 10 audio files
# Done with speaker 14, have 10 audio files
# Done with speaker 15, have 10 audio files
# Done with speaker 17, have 10 audio files
# Done with speaker 18, have 10 audio files
# Done with speaker 19, have 10 audio files
# Done with speaker 20, have 10 audio files
# Done with speaker 21, have 10 audio files
# Done with speaker 22, have 10 audio files
# Done with speaker 23, have 10 audio files
# Done with speaker 26, have 10 audio files
# ...

# %%
val_data_9sec.shape
# Out:
# (390, 4)

# %%
# Save data
pickle.dump(val_data_9sec, open(
'/Users/greenapple/project5/data/processed/val_data_9sec.pkl', 'wb'))

# %%
# Clean later:

# %%
val_path = '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean'
speaker_start = 0
speaker_stop = 2
f = process_files.files_for_modeling_10_audios_9_sec(val_path, speaker_start, speaker_stop)
f
# Out:
# Done with speaker 1, have 10 audio files
# Done with speaker 2, have 10 audio files
# ['/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/2412/153954/2412-153954-0015.flac',
#  '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/2412/153954/2412-153954-0014.flac',
#  '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/2412/153954/2412-153954-0018.flac',
#  '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/2412/153954/2412-153954-0009.flac',
#  '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/2412/153954/2412-153954-0004.flac',
#  '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/2412/153954/2412-153954-0000.flac',
#  '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/2412/153947/2412-153947-0008.flac',
#  '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/2412/153947/2412-153947-0005.flac',
#  '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/2412/153947/2412-153947-0014.flac',
# ...

# %%
ff = '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean/2412/153954/2412-153954-0015.flac'
Xdb_3D, Xdb_resized, y, name_file, Xdb_rescaled = process_audio.one_observation_9_sec(ff)

# %%
Xdb_3D.shape
# Out:
# (224, 224, 3)

# %%
Xdb_resized.shape
# Out:
# (224, 672)

# %%
Xdb_rescaled.shape
# Out:
# (257, 721)

# %%
VGG16_features_9_sec

# %%
# Process audio files and add extracted features to a dataframe. Longer, 9 sec audios.
val_path = '/Users/greenapple/project5/data/raw/LibriSpeech/dev-clean'
speaker_start = 0
speaker_stop = 2

# Dataframe for 40 speakers (all)
val_data_9sec = audio_to_features.VGG16_features_9_sec(val_path, 
                                                       speaker_start, 
                                                       speaker_stop)
# Out:
# Done with speaker 1, have 10 audio files
# Done with speaker 2, have 10 audio files
# WARNING:tensorflow:From /Users/greenapple/anaconda3/envs/project4/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
val_data_t.shape
# Out:
# (20, 4)

# %% [markdown]
# ## Train data

# %%
# Use this cell to extract data:
# Process audio files and add extracted features to a dataframe. Longer, 9 sec audios.
train_path = '/Users/greenapple/project5/data/raw/LibriSpeech/train-clean-360'
speaker_start = 0
speaker_stop = 900

# Dataframe for 900 speakers (all)
train_data_9sec = audio_to_features.VGG16_features_9_sec(train_path, 
                                                       speaker_start, 
                                                       speaker_stop)
# Out:
# Done with speaker 1, have 10 audio files
# Done with speaker 2, have 10 audio files
# Done with speaker 3, have 10 audio files
# Done with speaker 4, have 10 audio files
# Done with speaker 5, have 10 audio files
# Done with speaker 6, have 10 audio files
# Done with speaker 7, have 10 audio files
# Done with speaker 8, have 10 audio files
# Done with speaker 9, have 10 audio files
# Done with speaker 10, have 10 audio files
# Done with speaker 11, have 10 audio files
# Done with speaker 12, have 10 audio files
# Done with speaker 13, have 10 audio files
# Done with speaker 14, have 10 audio files
# Done with speaker 15, have 10 audio files
# Done with speaker 16, have 10 audio files
# Done with speaker 17, have 10 audio files
# Done with speaker 18, have 10 audio files
# Done with speaker 19, have 10 audio files
# Done with speaker 20, have 10 audio files
# Done with speaker 21, have 10 audio files
# Done with speaker 22, have 10 audio files
# ...

# %%
# Save data
pickle.dump(train_data_9sec, open(
'/Users/greenapple/project5/data/processed/train_data_9sec.pkl', 'wb'))
